# %% [markdown]
# ## Stacks & Queues
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Q1. (stack) Implement the stack data structure using a linked list.

# %% [markdown]
# #### Q2. (stack) <font color="blue"> Using the stack in Q1 </font>, Write and test a program that extracts postfix expressions from the user, evaluates the expression, and prints the results. You may require that the user enter numeric values along with the operators and that each component of the expression be separated with white space.

# %% [markdown]
# #### Q3. (stack) <font color="blue"> Using the stack in Q1 </font>, write a program to check for balanced parentheses, brackets and braces. The program also ignores these symbols when they are part of a comment (lines beginning with //).
#
# - For example, the following snippet is valid:<br/>
#     `int values (int arr[]) // (this is fun!`
#
# - And this is not:<br/>
#     `int values (int arr[])] // (this is fun!`

# %% [markdown]
# #### Q4. (queue) Implement the queue data structure using a singly linked list.

# %% [markdown]
# #### Q5. (queue) Implement the Priority Queue ADT using an unsorted linked list.

# %% [markdown]
# #### Q6. (queue) A <font color="blue"> deque (pronounced “deck”) </font> is similar to a queue, except that elements can be enqueued at either end and dequeued from either end. Define a Deque ADT and then provide an implementation for your definition.
#
# ![image.png](attachment:image.png)
